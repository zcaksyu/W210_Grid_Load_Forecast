# %%
pip install cdo-api-py
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
from cdo_api_py import Client
import pandas as pd
from datetime import datetime
from pprint import pprint
token = "TLoDgnwiTzafyuFOYEkzuSSmtsBLetLe" # be sure not to share your token publicly
my_client = Client(token, default_units='metric', default_limit=1000)

# %%
# bbox:           xmin: -73.95187 ymin: 40.79249 xmax: -73.95187 ymax: 40.79249
extent = {
"north": 39.14,
"south": 38.68,
"east": -76.65,
"west": -77.35,
}

startdate = datetime(2016, 12, 1)
enddate = datetime(2016, 12, 31)

datasetid='GHCND'
datatypeid=['TMIN', 'TMAX', 'PRCP']

# %%
stations = my_client.find_stations(
datasetid=datasetid,
extent=extent,
startdate=startdate,
enddate=enddate,
datatypeid=datatypeid,
return_dataframe=True)
pprint(stations)
# Out:
# https://www.ncdc.noaa.gov/cdo-web/api/v2/stations?datasetid=GHCND&startdate=2016-12-01&enddate=2016-12-31&extent=38.68&extent=-77.35&extent=39.14&extent=-76.65&datatypeid=TMIN&datatypeid=TMAX&datatypeid=PRCP&limit=1000&units=metric
#    elevation     mindate     maxdate  latitude  \
# 0       44.2  1941-05-01  2023-01-27  39.03020
# 1       45.7  1948-08-01  2022-12-31  38.93850
# 2       15.2  1948-08-01  2022-11-30  38.91329
# 3       57.9  2002-06-01  2021-07-24  38.79550
# 4      118.9  1925-04-01  2023-01-31  38.89205
# 5        4.1  1936-09-01  2023-01-31  38.84721
#
#                                         name  datacoverage                 id  \
# 0                          BELTSVILLE, MD US        0.8085  GHCND:USC00180700
# 1                DALECARLIA RESERVOIR, DC US        0.8245  GHCND:USC00182325
# 2               NATIONAL ARBORETUM DC, DC US        0.8116  GHCND:USC00186350
# 3                           OXON HILL, MD US        0.8370  GHCND:USC00186800
# ...

# %%
stations
# Out:
#    elevation     mindate     maxdate  latitude  \
# 0       44.2  1941-05-01  2023-01-27  39.03020
# 1       45.7  1948-08-01  2022-12-31  38.93850
# 2       15.2  1948-08-01  2022-11-30  38.91329
# 3       57.9  2002-06-01  2021-07-24  38.79550
# 4      118.9  1925-04-01  2023-01-31  38.89205
# 5        4.1  1936-09-01  2023-01-31  38.84721
#
#                                         name  datacoverage                 id  \
# 0                          BELTSVILLE, MD US        0.8085  GHCND:USC00180700
# 1                DALECARLIA RESERVOIR, DC US        0.8245  GHCND:USC00182325
# 2               NATIONAL ARBORETUM DC, DC US        0.8116  GHCND:USC00186350
# 3                           OXON HILL, MD US        0.8370  GHCND:USC00186800
# 4                              VIENNA, VA US        0.7204  GHCND:USC00448737
# 5  WASHINGTON REAGAN NATIONAL AIRPORT, VA US        0.7957  GHCND:USW00013743
#
#   elevationUnit  longitude
# 0        METERS  -76.93150
# 1        METERS  -77.11340
# ...

# %%
for rowid, station in stations.iterrows():
  station_data = my_client.get_data_by_station(datasetid=datasetid,stationid=station['id'],startdate=startdate,enddate=enddate,return_dataframe=True,include_station_meta=True)
  pprint(station_data)
# Out:
# https://www.ncdc.noaa.gov/cdo-web/api/v2/stations/GHCND:USC00180700?limit=1000&units=metric
# https://www.ncdc.noaa.gov/cdo-web/api/v2/data?datasetid=GHCND&startdate=2016-12-01&enddate=2016-12-31&stationid=GHCND:USC00180700&limit=1000&units=metric
#               station                 date  PRCP  SNOW  SNWD  TMAX  TMIN  \
# 0   GHCND:USC00180700  2016-12-01T00:00:00  30.7   0.0   0.0  20.0  10.6
# 1   GHCND:USC00180700  2016-12-02T00:00:00   0.0   0.0   0.0  12.8   5.6
# 2   GHCND:USC00180700  2016-12-03T00:00:00   0.0   0.0   0.0  10.0   5.0
# 3   GHCND:USC00180700  2016-12-04T00:00:00   0.0   0.0   0.0   8.9   2.2
# 4   GHCND:USC00180700  2016-12-05T00:00:00   7.9   0.0   0.0   7.8   2.8
# 5   GHCND:USC00180700  2016-12-06T00:00:00   0.0   0.0   0.0  11.7   2.8
# 6   GHCND:USC00180700  2016-12-07T00:00:00  23.1   0.0   0.0   6.7   4.4
# 7   GHCND:USC00180700  2016-12-08T00:00:00   0.0   0.0   0.0   9.4  -1.1
# ...
